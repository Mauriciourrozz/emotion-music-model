# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from src.labeling import assign_emotion
import pandas as pd

# %%
df = pd.read_csv("../data/raw/spotify_dataset_1921_2020.csv")

# %%
df.head()
# Out:
#    valence  year  acousticness  \
# 0   0.0594  1921         0.982
# 1   0.9630  1921         0.732
# 2   0.0394  1921         0.961
# 3   0.1650  1921         0.967
# 4   0.2530  1921         0.957
#
#                                              artists  danceability  \
# 0  ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                     ['Dennis Day']         0.819
# 2  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                   ['Frank Parker']         0.275
# 4                                     ['Phil Regan']         0.418
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz          0.878000
# 1       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8          0.000000
# 2       500062   0.166         0  1o6I8BglA6ylDMrIELygv1          0.913000
# ...

# %%
df = df[['valence', 'name', 'energy', 'danceability', 'acousticness', 'artists', 'year']]
df.head()
# Out:
#    valence                                               name  energy  \
# 0   0.0594  Piano Concerto No. 3 in D Minor, Op. 30: III. ...   0.211
# 1   0.9630                            Clancy Lowered the Boom   0.341
# 2   0.0394                                          Gati Bali   0.166
# 3   0.1650                                          Danny Boy   0.309
# 4   0.2530                        When Irish Eyes Are Smiling   0.193
#
#    danceability  acousticness  \
# 0         0.279         0.982
# 1         0.819         0.732
# 2         0.328         0.961
# 3         0.275         0.967
# 4         0.418         0.957
#
#                                              artists  year
# 0  ['Sergei Rachmaninoff', 'James Levine', 'Berli...  1921
# 1                                     ['Dennis Day']  1921
# 2  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...  1921
# 3                                   ['Frank Parker']  1921
# 4                                     ['Phil Regan']  1921

# %%
df["emotions"] = df.apply(assign_emotion, axis=1)

# %%
df["emotions"].value_counts()
# Out:
# emotions
# neutral    71795
# joy        44126
# sadness    36188
# anger      13083
# fear        5461
# Name: count, dtype: int64

# %%
import os
os.makedirs("../data/processed", exist_ok=True)
df.to_csv("../data/processed/spotify_processed.csv", index=False)
